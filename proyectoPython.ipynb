# %%
#libreria para el control de los datos del archivo
import pandas
#lee el archivo 
df = pandas.read_csv('/home/jose/Escritorio/proyecto/jupyter/centros-de-salud-2012.csv',encoding="cp1252", sep=";")
df
# Out:
#      Tipo de centro de salud         Provincia                 Canton  \
# 0            CENTRO DE SALUD             AZUAY  CAMILO PONCE ENRIQUEZ
# 1            CENTRO DE SALUD             AZUAY  CAMILO PONCE ENRIQUEZ
# 2            CENTRO DE SALUD             AZUAY  CAMILO PONCE ENRIQUEZ
# 3            CENTRO DE SALUD             AZUAY              CHORDELEG
# 4            CENTRO DE SALUD             AZUAY              CHORDELEG
# 5            CENTRO DE SALUD             AZUAY                 CUENCA
# 6            CENTRO DE SALUD             AZUAY                 CUENCA
# 7            CENTRO DE SALUD             AZUAY                 CUENCA
# 8            CENTRO DE SALUD             AZUAY                 CUENCA
# 9            CENTRO DE SALUD             AZUAY                 CUENCA
# 10           CENTRO DE SALUD             AZUAY                 CUENCA
# 11           CENTRO DE SALUD             AZUAY                 CUENCA
# 12           CENTRO DE SALUD             AZUAY                 CUENCA
# 13           CENTRO DE SALUD             AZUAY                 CUENCA
# 14           CENTRO DE SALUD             AZUAY                 CUENCA
# 15           CENTRO DE SALUD             AZUAY                 CUENCA
# 16           CENTRO DE SALUD             AZUAY                 CUENCA
# 17           CENTRO DE SALUD             AZUAY                 CUENCA
# 18           CENTRO DE SALUD             AZUAY                 CUENCA
# 19           CENTRO DE SALUD             AZUAY                 CUENCA
# 20           CENTRO DE SALUD             AZUAY                 CUENCA
# 21           CENTRO DE SALUD             AZUAY                 CUENCA
# 22           CENTRO DE SALUD             AZUAY                 CUENCA
# 23           CENTRO DE SALUD             AZUAY                 CUENCA
# 24           CENTRO DE SALUD             AZUAY                 CUENCA
# 25           CENTRO DE SALUD             AZUAY                 CUENCA
# 26           CENTRO DE SALUD             AZUAY                 CUENCA
# 27           CENTRO DE SALUD             AZUAY                 CUENCA
# 28           CENTRO DE SALUD             AZUAY                 CUENCA
# 29           CENTRO DE SALUD             AZUAY                 CUENCA
# ...                      ...               ...                    ...
# 2678         PUESTO DE SALUD  ZAMORA CHINCHIPE             NANGARITZA
# 2679         PUESTO DE SALUD  ZAMORA CHINCHIPE             NANGARITZA
# 2680         PUESTO DE SALUD  ZAMORA CHINCHIPE             NANGARITZA
# 2681         PUESTO DE SALUD  ZAMORA CHINCHIPE                PALANDA
# 2682         PUESTO DE SALUD  ZAMORA CHINCHIPE                PALANDA
# 2683         PUESTO DE SALUD  ZAMORA CHINCHIPE                PALANDA
# 2684         PUESTO DE SALUD  ZAMORA CHINCHIPE                PALANDA
# 2685         PUESTO DE SALUD  ZAMORA CHINCHIPE               PAQUISHA
# 2686         PUESTO DE SALUD  ZAMORA CHINCHIPE               PAQUISHA
# 2687         PUESTO DE SALUD  ZAMORA CHINCHIPE               PAQUISHA
# 2688         PUESTO DE SALUD  ZAMORA CHINCHIPE               YACUAMBI
# 2689         PUESTO DE SALUD  ZAMORA CHINCHIPE               YACUAMBI
# 2690         PUESTO DE SALUD  ZAMORA CHINCHIPE               YACUAMBI
# 2691         PUESTO DE SALUD  ZAMORA CHINCHIPE               YACUAMBI
# 2692         PUESTO DE SALUD  ZAMORA CHINCHIPE               YANTZAZA
# 2693         PUESTO DE SALUD  ZAMORA CHINCHIPE               YANTZAZA
# 2694         PUESTO DE SALUD  ZAMORA CHINCHIPE               YANTZAZA
# 2695         PUESTO DE SALUD  ZAMORA CHINCHIPE               YANTZAZA
# 2696         PUESTO DE SALUD  ZAMORA CHINCHIPE                 ZAMORA
# 2697         PUESTO DE SALUD  ZAMORA CHINCHIPE                 ZAMORA
# 2698         PUESTO DE SALUD  ZAMORA CHINCHIPE                 ZAMORA
# 2699         PUESTO DE SALUD  ZAMORA CHINCHIPE                 ZAMORA
# 2700         PUESTO DE SALUD  ZAMORA CHINCHIPE                 ZAMORA
# 2701         PUESTO DE SALUD  ZAMORA CHINCHIPE                 ZAMORA
# 2702         PUESTO DE SALUD  ZAMORA CHINCHIPE                 ZAMORA
# 2703         PUESTO DE SALUD   ZONA DELIMITADA            EL PIEDRERO
# 2704         PUESTO DE SALUD   ZONA DELIMITADA            EL PIEDRERO
# 2705         PUESTO DE SALUD   ZONA DELIMITADA        LAS GOLONDRINAS
# 2706         PUESTO DE SALUD   ZONA DELIMITADA        LAS GOLONDRINAS
# 2707         PUESTO DE SALUD   ZONA DELIMITADA         MANGA DEL CURA
#
#                                  Parroquia  \
# 0                    CAMILO PONCE ENRIQUEZ
# 1                    CAMILO PONCE ENRIQUEZ
# 2                    CAMILO PONCE ENRIQUEZ
# 3                                CHORDELEG
# 4                                PRINCIPAL
# 5                                  CHAUCHA
# 6                           CHECA (JIDCAY)
# 7                               CHIQUINTAD
# 8                               CHIQUINTAD
# 9                                   CUENCA
# 10                                  CUENCA
# 11                                  CUENCA
# 12                                  CUENCA
# 13                                  CUENCA
# 14                                  CUENCA
# 15                                  CUENCA
# 16                                  CUENCA
# 17                                  CUENCA
# 18                                  CUENCA
# 19                                  CUENCA
# 20                                  CUENCA
# 21                                  CUENCA
# 22                                  CUENCA
# 23                                  CUENCA
# 24                                  CUENCA
# 25                                   CUMBE
# 26                                  LLACAO
# 27                               MOLLETURO
# 28                                   NULTI
# 29    OCTAVIO CORDERO PALACIOS (STA. ROSA)
# ...                                    ...
# 2678                                 ZURMI
# 2679                                 ZURMI
# 2680                                 ZURMI
# 2681                EL PORVENIR DEL CARMEN
# 2682                             LA CANELA
# 2683                               PALANDA
# 2684              SAN FRANCISCO DEL VERGEL
# 2685                            BELLAVISTA
# 2686                           NUEVO QUITO
# 2687                           NUEVO QUITO
# 2688     28 DE MAYO (SAN JOSE DE YACUAMBI)
# 2689                                LA PAZ
# 2690                                LA PAZ
# 2691                              TUTUPALI
# 2692                              CHICANIA
# 2693                        LOS ENCUENTROS
# 2694                        LOS ENCUENTROS
# 2695                   YANTZAZA (YANZATZA)
# 2696                             GUADALUPE
# 2697                             GUADALUPE
# 2698                             GUADALUPE
# 2699                             GUADALUPE
# 2700               SAN CARLOS DE LAS MINAS
# 2701                               TIMBARA
# 2702                                ZAMORA
# 2703                           EL PIEDRERO
# 2704                           EL PIEDRERO
# 2705                       LAS GOLONDRINAS
# 2706                       LAS GOLONDRINAS
# 2707                        MANGA DEL CURA
#
#                                                Distrito  \
# 0                                 CAMILO PONCE ENRIQUEZ
# 1                                 CAMILO PONCE ENRIQUEZ
# 2                                 CAMILO PONCE ENRIQUEZ
# 3                                    GUALACEO-CHORDELEG
# 4                                    GUALACEO-CHORDELEG
# 5     BANIOS-CUMBE-CHAUCHA-MOLLETURO-TURI-VALLE-VICT...
#
# 2691                           1   -3.52948  -78.951615
# 2692                           1  -3.692993  -78.777098
# 2693                           1  -3.759457  -78.650029
# 2694                           1  -3.840503  -78.572571
# 2695                           1  -3.776532  -78.745165
# 2696                           1  -3.804128  -78.897508
# 2697                           1  -3.870803  -78.878911
# 2698                           1  -3.912287  -78.877304
# 2699                           1  -3.905095  -78.882506
# 2700                           1  -4.072739  -78.789554
# 2701                           1  -4.030802  -78.898589
# 2702                           1  -4.132147  -78.942149
# 2703                           1  -2.394802  -79.294985
# 2704                           1  -2.340603  -79.241749
# 2705                           1    0.27939   -78.99787
# 2706                           1   0.320905  -79.212099
# 2707                           1  -0.812327  -79.640999
#
# [2708 rows x 11 columns]

# %%
#extrae todos los datos de la columna. "Tipo de centro de salud"
tipos = list((df['Tipo de centro de salud']))

# %%
#eliminar valores repetidos o filtar los datos de la lista
lit = list(set(tipos))
numCS =tipos.count(lit[0])
numHB =tipos.count(lit[1])
numHDE =tipos.count(lit[2])
numHE =tipos.count(lit[3])
numHG =tipos.count(lit[4])
numPS =tipos.count(lit[5])
lit
# Out:
# ['HOSPITAL GENERAL',
#  'PUESTO DE SALUD',
#  'HOSPITAL BASICO',
#  'CENTRO DE SALUD',
#  'HOSPITAL DE ESPECIALIDADES',
#  'HOSPITAL ESPECIALIZADO']

# %%
#libreria para realizar las graficas
from bokeh.io import show, output_file
from bokeh.plotting import figure
#enviar parametros para realizar la figura
#w_range valores de x
#plot_width, plot_height define el tamaño de la grafica
#title nombre de la grafica
#toolbar_location posicion de la barra de opciones
#tools opciones de descarga, carga, etc
p = figure(x_range=lit, plot_width=1010, plot_height=350, title="Número de Centro de Salud",
           toolbar_location="below", tools="")
#definir parametros de la grafica eje x, y y tamaño de las barras
p.vbar(x=lit, top = [numHE,numHB,numHDE,numCS,numHG,numPS], width=0.6)
#no enivar colores a las barras
p.xgrid.grid_line_color = None
p.y_range.start = 0
#visualizar la grafica
show(p)
# Out:
# W-1005 (SNAPPED_TOOLBAR_ANNOTATIONS): Snapped toolbars and annotations on the same side MAY overlap visually: Figure(id='35bd1781-408e-4565-8436-44243dab74c3', ...)

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

fruits = lit
top = [numHE,numHB,numHDE,numCS,numHG,numPS]
counts = top
source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))
p = figure(x_range=fruits,plot_width=1010, plot_height=500, toolbar_location=None, title="Numero de Centro de Salud")
p.vbar(x='fruits', top='counts', width=0.2, source=source, legend="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 1700
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# W-1005 (SNAPPED_TOOLBAR_ANNOTATIONS): Snapped toolbars and annotations on the same side MAY overlap visually: Figure(id='35bd1781-408e-4565-8436-44243dab74c3', ...)

# %%
#datos de la columna Provincia
prov = list((df['Provincia']))
#valors unicos tranformado en una lista para resivir informacion
uni = list(set(prov))
#selecciona solo los 5 primeras provincias 
uni2 = uni[0:5]
uni2
# Out:
# ['LOS RIOS', 'AZUAY', 'SUCUMBIOS', 'GUAYAS', 'MANABI']

# %%
#mesclar valores en dos lista 
datos = [(x, y) for x in lit for y in uni2 if x != y]
datos
# Out:
# [('HOSPITAL GENERAL', 'LOS RIOS'),
#  ('HOSPITAL GENERAL', 'AZUAY'),
#  ('HOSPITAL GENERAL', 'SUCUMBIOS'),
#  ('HOSPITAL GENERAL', 'GUAYAS'),
#  ('HOSPITAL GENERAL', 'MANABI'),
#  ('PUESTO DE SALUD', 'LOS RIOS'),
#  ('PUESTO DE SALUD', 'AZUAY'),
#  ('PUESTO DE SALUD', 'SUCUMBIOS'),
#  ('PUESTO DE SALUD', 'GUAYAS'),
#  ('PUESTO DE SALUD', 'MANABI'),
#  ('HOSPITAL BASICO', 'LOS RIOS'),
#  ('HOSPITAL BASICO', 'AZUAY'),
#  ('HOSPITAL BASICO', 'SUCUMBIOS'),
#  ('HOSPITAL BASICO', 'GUAYAS'),
#  ('HOSPITAL BASICO', 'MANABI'),
#  ('CENTRO DE SALUD', 'LOS RIOS'),
#  ('CENTRO DE SALUD', 'AZUAY'),
#  ('CENTRO DE SALUD', 'SUCUMBIOS'),
#  ('CENTRO DE SALUD', 'GUAYAS'),
#  ('CENTRO DE SALUD', 'MANABI'),
#  ('HOSPITAL DE ESPECIALIDADES', 'LOS RIOS'),
#  ('HOSPITAL DE ESPECIALIDADES', 'AZUAY'),
#  ('HOSPITAL DE ESPECIALIDADES', 'SUCUMBIOS'),
#  ('HOSPITAL DE ESPECIALIDADES', 'GUAYAS'),
#  ('HOSPITAL DE ESPECIALIDADES', 'MANABI'),
#  ('HOSPITAL ESPECIALIZADO', 'LOS RIOS'),
#  ('HOSPITAL ESPECIALIZADO', 'AZUAY'),
#  ('HOSPITAL ESPECIALIZADO', 'SUCUMBIOS'),
#  ('HOSPITAL ESPECIALIZADO', 'GUAYAS'),
#  ('HOSPITAL ESPECIALIZADO', 'MANABI')]

# %%
num1=len(df[(df['Tipo de centro de salud'] == lit[0]) & (df['Provincia'] == uni2[0])])
num2=len(df[(df['Tipo de centro de salud'] == lit[0]) & (df['Provincia'] == uni2[1])])
num3=len(df[(df['Tipo de centro de salud'] == lit[0]) & (df['Provincia'] == uni2[2])])
num4=len(df[(df['Tipo de centro de salud'] == lit[0]) & (df['Provincia'] == uni2[3])])
num5=len(df[(df['Tipo de centro de salud'] == lit[1]) & (df['Provincia'] == uni2[0])])
num6=len(df[(df['Tipo de centro de salud'] == lit[1]) & (df['Provincia'] == uni2[1])])
num7=len(df[(df['Tipo de centro de salud'] == lit[1]) & (df['Provincia'] == uni2[2])])
num8=len(df[(df['Tipo de centro de salud'] == lit[1]) & (df['Provincia'] == uni2[3])])
num9=len(df[(df['Tipo de centro de salud'] == lit[2]) & (df['Provincia'] == uni2[0])])
num10=len(df[(df['Tipo de centro de salud'] == lit[2]) & (df['Provincia'] == uni2[1])])
num11=len(df[(df['Tipo de centro de salud'] == lit[2]) & (df['Provincia'] == uni2[2])])
num12=len(df[(df['Tipo de centro de salud'] == lit[2]) & (df['Provincia'] == uni2[3])])
num13=len(df[(df['Tipo de centro de salud'] == lit[3]) & (df['Provincia'] == uni2[0])])
num14=len(df[(df['Tipo de centro de salud'] == lit[3]) & (df['Provincia'] == uni2[1])])
num15=len(df[(df['Tipo de centro de salud'] == lit[3]) & (df['Provincia'] == uni2[2])])
num16=len(df[(df['Tipo de centro de salud'] == lit[3]) & (df['Provincia'] == uni2[3])])
num17=len(df[(df['Tipo de centro de salud'] == lit[4]) & (df['Provincia'] == uni2[0])])
num18=len(df[(df['Tipo de centro de salud'] == lit[4]) & (df['Provincia'] == uni2[1])])
num19=len(df[(df['Tipo de centro de salud'] == lit[4]) & (df['Provincia'] == uni2[2])])
num20=len(df[(df['Tipo de centro de salud'] == lit[4]) & (df['Provincia'] == uni2[3])])
num21=len(df[(df['Tipo de centro de salud'] == lit[5]) & (df['Provincia'] == uni2[0])])
num22=len(df[(df['Tipo de centro de salud'] == lit[5]) & (df['Provincia'] == uni2[1])])
num23=len(df[(df['Tipo de centro de salud'] == lit[5]) & (df['Provincia'] == uni2[2])])
num24=len(df[(df['Tipo de centro de salud'] == lit[5]) & (df['Provincia'] == uni2[3])])

# %%
from bokeh.io import show, output_file
from bokeh.models import FactorRange
from bokeh.plotting import figure
p = figure(x_range=FactorRange(*datos),plot_width=1010, plot_height=500,
           toolbar_location=None, tools="",title="Número de Centro de Salud")
x = [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10,num11,num12,num13,num14,num15,num16,num17,num18,num19,num20
     ,num21,num22,num23,num24]
p.vbar(x=datos, top=x, width=0.9, alpha=0.5)
p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)
# Out:
# /home/jose/Escritorio/entornos/jupiter/lib/python3.5/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('top', 24), ('x', 30)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# W-1005 (SNAPPED_TOOLBAR_ANNOTATIONS): Snapped toolbars and annotations on the same side MAY overlap visually: Figure(id='35bd1781-408e-4565-8436-44243dab74c3', ...)

# %%
#extraer datos que solo sehan de PUESTO DE SALUD y tungurahua
tungu =df[(df['Tipo de centro de salud'] == "PUESTO DE SALUD") & (df['Provincia'] == "TUNGURAHUA")]
#obtener latitud y lonngitud solo de los datos antes seleccionados
tunguLat = list((tungu['Latitud']))
tunguLog = list((tungu['Longitud']))
#transformarlos de cadena a numero decimal y tranformado a una lista
lat1 = list(map(float, tunguLat))
log1 = list(map(float, tunguLog))

# %%
from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
#graficar el area de que se desea visualizar
map_options = GMapOptions(lat=-1.400, lng=-78.600, map_type="roadmap", zoom=10)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options
)
plot.title.text = "Ecuador: Tungurahua - Puesto de Salud"
plot.api_key = "AIzaSyCbID1mffiXrc_1wQswHhbL-IDUICEtTA0"

source = ColumnDataSource(
    data=dict(
        lat=lat1,
        lon=log1,
    )
)

circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
show(plot)
# Out:
# W-1005 (SNAPPED_TOOLBAR_ANNOTATIONS): Snapped toolbars and annotations on the same side MAY overlap visually: Figure(id='24f8fca3-b91e-45a8-a584-a7664e6a0f03', ...)
